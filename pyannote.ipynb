# %%
from pyannote.audio import Pipeline
pipeline = Pipeline.from_pretrained("pyannote/speaker-diarization")

# %%
dia = pipeline("seattle-2021-proto/audio/7fe4c0d99b44.wav")

# %%
from pyannote.core import notebook, Segment
notebook.crop = Segment(0, 120)
dia

# %%
notebook.crop = Segment(120, 240)
dia

# %%
notebook.crop = Segment(240, 360)
dia

# %%
notebook.crop = Segment(360, 480)
dia

# %%
notebook.crop = Segment(480, 600)
dia

# %%
notebook.crop = Segment(600, 840)
dia

# %%
notebook.crop = Segment(840, 1080)
dia

# %%
notebook.crop = None
dia
